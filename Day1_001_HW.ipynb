# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w=3
b=0.5
x_lin=np.linspace(0,100,101)
y = (x_lin + np.random.randn(101) * 5) * w + b
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error
MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.055

# %%
from sklearn.metrics import mean_squared_error
MSE=mean_squared_error(y,y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 227.023

# %% [markdown]
# 第二題作業

# %% [markdown]
# https://www.kaggle.com/c/digit-recognizer
#     手寫數字圖像辨識
#     1. 你選的這組資料為何重要
#        這組資料集在機器學習入門中很有名,感覺是想學圖形辨識需要接觸的第一筆數據集
#        題目較簡單化只需要辨識數字分類,對於初學者也比較容易上手
#     2. 資料從何而來
#        在Python中有內建mnist數據集,直接下載就可以,免去初學者剛學習就要找資料的麻煩
#     3. 蒐集而來的資料型態為何
#        圖片檔
#     4. 這組資料想解決的問題如何評估
#        透過訓練集訓練的模型,應用在測試集上查看預測的值準確率

# %% [markdown]
# 第三題作業

# %% [markdown]
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#    針對重要客流時段、車隊數量、客戶需求量等作分析，並針對弱項透過其他手法增加行銷
#    若是客流熱門時段車隊量不足就對員工增加誘因，給予此時段獎金bonus，或開放零散上班族
#    可利用閒暇時間兼差,若是客戶群尚未開發就針對銷售族群促銷,老年族群可推出關懷老人方案
#    設計無障礙車輛供應客戶需求,中年族群可能有些是出差人士,可配套出差天數包車措施或旅館
#    折扣,青年族群多為遊玩且經濟能力較不足,提供拼車服務或學生證折扣,青中年可透過社群媒體
#    行銷,或抽獎免費乘坐一趟等等
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#    https://www.grb.gov.tw/search/report/12991480
#    網路上有一些關於計程車的開放資料集可供參考,同時也可在網上投放問卷,並分析客群
# 3. 蒐集而來的資料型態為何
#    文字檔(字串,數字)
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#    客流量,乘車量,體驗率,連單率,回客率等
